# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My Drive/ann challenge
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/ann challenge

# %% [markdown]
# ### Import libraries

# %%
# Fix randomness and hide warnings
seed = 42

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

import random
random.seed(seed)

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
print(tf.__version__)
# Out:
# 2.15.0

# %%
# Import other libraries
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
from sklearn.utils import shuffle
import seaborn as sns
plt.rc('font', size=16)
sns.set_theme()

# %% [markdown]
# ## Auxiliary functions

# %%
def plot_images(X, y, num_images=7, start_index=0) -> None:
  plt.figure(figsize=(12, 12))
  for i in range(num_images**2):
    _ = plt.subplot(num_images, num_images, i + 1)
    plt.imshow(X[start_index+i].astype(np.uint8))
    plt.title(f'{y[start_index+i]}', fontsize=8)
    plt.axis("off")
  plt.show()

# %%
def plot_history(history, log_scale: bool = False) -> None:
  mae = history['mae']
  val_mae = history['val_mae']
  loss = history['loss']
  val_loss = history['val_loss']
  best_epoch = np.argmin(val_loss)

  plt.figure(figsize=(18, 6))
  plt.subplot(1, 2, 1)
  plt.title('Training and validation MSE')
  plt.xlabel('Epoch')
  plt.ylabel('Mean Squared Error')

  if log_scale:
      plt.semilogy(loss, label='Training MSE', color='#ff7f0e')
      plt.semilogy(val_loss, label='Validation MSE', color='#4D61E2')
  else:
      plt.plot(loss, label='Training MSE', color='#ff7f0e')
      plt.plot(val_loss, label='Validation MSE', color='#4D61E2')

  plt.plot(best_epoch, history['val_loss'][best_epoch], marker='*', alpha=0.8, markersize=10, color='#4D61E2')
  plt.grid(True)
  plt.legend()

  plt.subplot(1, 2, 2)
  plt.title('Training and validation MAE')
  plt.xlabel('Epoch')
  plt.ylabel('Mean Absolute Error')

  if log_scale:
     plt.semilogy(mae, label='Training MAE', color='#ff7f0e')
     plt.semilogy(val_mae, label='Validation MAE', color='#4D61E2')
  else:
    plt.plot(mae, label='Training MAE', color='#ff7f0e')
    plt.plot(val_mae, label='Validation MAE', color='#4D61E2')

  plt.plot(best_epoch, history['val_mae'][best_epoch], marker='*', alpha=0.8, markersize=10, color='#4D61E2')
  plt.grid(True)
  plt.legend()
  plt.show()

# %%
def plot_data_and_target(data, target, original = None):
  # Remove padding from the data
  data = data[np.nonzero(data)[0][0]:]
  # Generate indexes to align the time stamps
  indexes = np.arange(0, len(data) + len(target))

  # Plot the new data and the new target
  plt.figure(figsize=(16, 4))
  plt.plot(indexes[:len(data)], data, label='data', linewidth=2)
  plt.plot(indexes[len(data):], target, label='target', linewidth=2)

  if original is not None:
    # Plot the original data
    plt.plot(indexes, original, label='original', linestyle='--')

  plt.title("Time series")
  plt.legend()
  plt.show()

# %% [markdown]
# ## Load data

# %%
data = np.load('preprocessed_data_window.npz', allow_pickle=True)

# %%
X_train, X_val, y_train, y_val = data["X_train"], data["X_val"], data["y_train"], data["y_val"]

# %%
X_train = np.expand_dims(X_train, axis=-1)
X_val = np.expand_dims(X_val, axis=-1)
y_train = np.expand_dims(y_train, axis=-1)
y_val= np.expand_dims(y_val, axis=-1)

# %%
print("Training Data Shape:", X_train.shape)
print("Training Label Shape:", y_train.shape)
print("Validation Data Shape:", X_val.shape)
print("Validation Label Shape:", y_val.shape)
# Out:
# Training Data Shape: (66641, 200, 1)
# Training Label Shape: (66641, 9, 1)
# Validation Data Shape: (7405, 200, 1)
# Validation Label Shape: (7405, 9, 1)

# %% [markdown]
# ## Build the model

# %%
# Define key model parameters
input_shape = X_train.shape[1:]         # Input shape for the model
output_shape = y_train.shape[1:]        # Output shape for the model
batch_size = 256                        # Batch size for training
epochs = 200                            # Number of training epochs

# Print the defined parameters
print("Epochs:", epochs)
print("Batch Size:", batch_size)
print("Input Shape:", input_shape)
print("Output Shape:", output_shape)
# Out:
# Epochs: 200
# Batch Size: 256
# Input Shape: (200, 1)
# Output Shape: (9, 1)

# %%
def transformer_encoder(inputs, head_size, num_heads, feedforward_dim, head_dropout=0.0):
    # Normalization and Attention
    x = tfkl.LayerNormalization(epsilon=1e-6)(inputs)
    x = tfkl.MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=head_dropout)(x, x)
    x = tfkl.Dropout(head_dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = tfkl.LayerNormalization(epsilon=1e-6)(res)
    x = tfkl.Conv1D(filters=feedforward_dim, kernel_size=1, activation="relu")(x)
    x = tfkl.Dropout(head_dropout)(x)
    x = tfkl.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

# %%
initializer = tfk.initializers.HeUniform()

def build_model(input_shape, head_size, num_heads, feedforward_dim, num_transformer_blocks, mlp_units, telescope, head_dropout=0.0, mlp_dropout=0.0):
    inputs = tfk.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, feedforward_dim, head_dropout)

    x = tfkl.Flatten()(x)

    x = tfkl.Dense(units=4096, kernel_initializer=initializer)(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Activation('swish')(x)
    x = tfkl.Dropout(mlp_dropout)(x)

    x = tfkl.Dense(units=1024, kernel_initializer=initializer)(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Activation('swish')(x)
    x = tfkl.Dropout(mlp_dropout)(x)

    x = tfkl.Dense(units=256, kernel_initializer=initializer)(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Activation('swish')(x)
    x = tfkl.Dropout(mlp_dropout)(x)

    output_layer = tfkl.Dense(9, activation='linear')(x)

    # Construct the model by connecting input and output layers
    model = tf.keras.Model(inputs=inputs, outputs=output_layer, name='Vanilla_Transformer')

    # Compile the model with Mean Squared Error loss and Adam optimizer
    model.compile(loss=tf.keras.losses.MeanSquaredError(), optimizer=tf.keras.optimizers.AdamW(learning_rate=1e-3), metrics=['mae'])

    return model

# %%
model = build_model(
    input_shape,
    head_size=128, # 256
    num_heads=6, # 8
    num_transformer_blocks=4,
    feedforward_dim=4,
    mlp_units=[128],
    telescope=output_shape[0],
    head_dropout=0.35, # 0.4
    mlp_dropout=0.3 # 0.25
)
model.summary()
# Out:
# Model: "Vanilla_Transformer"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 200, 1)]             0         []
#
#  layer_normalization_8 (Lay  (None, 200, 1)               2         ['input_2[0][0]']
#  erNormalization)
#
#  multi_head_attention_4 (Mu  (None, 200, 1)               5377      ['layer_normalization_8[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_8[0][0]
#                                                                     ']
#
#  dropout_10 (Dropout)        (None, 200, 1)               0         ['multi_head_attention_4[0][0]
#                                                                     ']
#
#  tf.__operators__.add_8 (TF  (None, 200, 1)               0         ['dropout_10[0][0]',
#  OpLambda)                                                           'input_2[0][0]']
#
#  layer_normalization_9 (Lay  (None, 200, 1)               2         ['tf.__operators__.add_8[0][0]
#  erNormalization)                                                   ']
#
#  conv1d_8 (Conv1D)           (None, 200, 4)               8         ['layer_normalization_9[0][0]'
#                                                                     ]
#
#  dropout_11 (Dropout)        (None, 200, 4)               0         ['conv1d_8[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 200, 1)               5         ['dropout_11[0][0]']
#
#  tf.__operators__.add_9 (TF  (None, 200, 1)               0         ['conv1d_9[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_8[0][0]
#                                                                     ']
#
#  layer_normalization_10 (La  (None, 200, 1)               2         ['tf.__operators__.add_9[0][0]
#  yerNormalization)                                                  ']
#
#  multi_head_attention_5 (Mu  (None, 200, 1)               5377      ['layer_normalization_10[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_10[0][0]
#                                                                     ']
#
#  dropout_12 (Dropout)        (None, 200, 1)               0         ['multi_head_attention_5[0][0]
#                                                                     ']
#
#  tf.__operators__.add_10 (T  (None, 200, 1)               0         ['dropout_12[0][0]',
#  FOpLambda)                                                          'tf.__operators__.add_9[0][0]
#                                                                     ']
#
#  layer_normalization_11 (La  (None, 200, 1)               2         ['tf.__operators__.add_10[0][0
#  yerNormalization)                                                  ]']
#
#  conv1d_10 (Conv1D)          (None, 200, 4)               8         ['layer_normalization_11[0][0]
#                                                                     ']
#
#  dropout_13 (Dropout)        (None, 200, 4)               0         ['conv1d_10[0][0]']
#
#  conv1d_11 (Conv1D)          (None, 200, 1)               5         ['dropout_13[0][0]']
#
#  tf.__operators__.add_11 (T  (None, 200, 1)               0         ['conv1d_11[0][0]',
#  FOpLambda)                                                          'tf.__operators__.add_10[0][0
#                                                                     ]']
#
#  layer_normalization_12 (La  (None, 200, 1)               2         ['tf.__operators__.add_11[0][0
#  yerNormalization)                                                  ]']
#
#  multi_head_attention_6 (Mu  (None, 200, 1)               5377      ['layer_normalization_12[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_12[0][0]
#                                                                     ']
#
#  dropout_14 (Dropout)        (None, 200, 1)               0         ['multi_head_attention_6[0][0]
#                                                                     ']
#
#  tf.__operators__.add_12 (T  (None, 200, 1)               0         ['dropout_14[0][0]',
#  FOpLambda)                                                          'tf.__operators__.add_11[0][0
#                                                                     ]']
#
#  layer_normalization_13 (La  (None, 200, 1)               2         ['tf.__operators__.add_12[0][0
#  yerNormalization)                                                  ]']
#
#  conv1d_12 (Conv1D)          (None, 200, 4)               8         ['layer_normalization_13[0][0]
#                                                                     ']
#
#  dropout_15 (Dropout)        (None, 200, 4)               0         ['conv1d_12[0][0]']
#
#  conv1d_13 (Conv1D)          (None, 200, 1)               5         ['dropout_15[0][0]']
#
#  tf.__operators__.add_13 (T  (None, 200, 1)               0         ['conv1d_13[0][0]',
#  FOpLambda)                                                          'tf.__operators__.add_12[0][0
#                                                                     ]']
#
#  layer_normalization_14 (La  (None, 200, 1)               2         ['tf.__operators__.add_13[0][0
#  yerNormalization)                                                  ]']
#
#  multi_head_attention_7 (Mu  (None, 200, 1)               5377      ['layer_normalization_14[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_14[0][0]
#                                                                     ']
#
#  dropout_16 (Dropout)        (None, 200, 1)               0         ['multi_head_attention_7[0][0]
#                                                                     ']
#
#  tf.__operators__.add_14 (T  (None, 200, 1)               0         ['dropout_16[0][0]',
#  FOpLambda)                                                          'tf.__operators__.add_13[0][0
#                                                                     ]']
#
#  layer_normalization_15 (La  (None, 200, 1)               2         ['tf.__operators__.add_14[0][0
#  yerNormalization)                                                  ]']
#
#  conv1d_14 (Conv1D)          (None, 200, 4)               8         ['layer_normalization_15[0][0]
#                                                                     ']
#
#  dropout_17 (Dropout)        (None, 200, 4)               0         ['conv1d_14[0][0]']
#
#  conv1d_15 (Conv1D)          (None, 200, 1)               5         ['dropout_17[0][0]']
#
#  tf.__operators__.add_15 (T  (None, 200, 1)               0         ['conv1d_15[0][0]',
#  FOpLambda)                                                          'tf.__operators__.add_14[0][0
#                                                                     ]']
#
#  flatten_1 (Flatten)         (None, 200)                  0         ['tf.__operators__.add_15[0][0
#                                                                     ]']
#
#  dense_3 (Dense)             (None, 4096)                 823296    ['flatten_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 4096)                 16384     ['dense_3[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 4096)                 0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  dropout_18 (Dropout)        (None, 4096)                 0         ['activation_2[0][0]']
#
#  dense_4 (Dense)             (None, 1024)                 4195328   ['dropout_18[0][0]']
#
#  batch_normalization_3 (Bat  (None, 1024)                 4096      ['dense_4[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 1024)                 0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_19 (Dropout)        (None, 1024)                 0         ['activation_3[0][0]']
#
#  dense_5 (Dense)             (None, 256)                  262400    ['dropout_19[0][0]']
#
#  batch_normalization_4 (Bat  (None, 256)                  1024      ['dense_5[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 256)                  0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  dropout_20 (Dropout)        (None, 256)                  0         ['activation_4[0][0]']
#
#  dense_6 (Dense)             (None, 9)                    2313      ['dropout_20[0][0]']
#
# ==================================================================================================
# Total params: 5326417 (20.32 MB)
# Trainable params: 5315665 (20.28 MB)
# Non-trainable params: 10752 (42.00 KB)
# __________________________________________________________________________________________________

# %%
tfk.utils.plot_model(model, show_shapes=True)

# %%
lr_patience = 10
es_patience = 25
callbacks = [
    tfk.callbacks.TerminateOnNaN(),
    tfk.callbacks.ReduceLROnPlateau('val_loss', patience=lr_patience, factor=0.3, min_lr=1e-5, verbose=1),
    tfk.callbacks.EarlyStopping('val_loss', patience=es_patience, restore_best_weights=True, verbose=1)
]

callbacks.append(tfk.callbacks.ModelCheckpoint(filepath='checkpoints/' + model.name + '/', save_weights_only=False, monitor='val_loss', mode='min', save_best_only=True))

# %% [markdown]
# ## Train model

# %%
# Train the model and save its history
history = model.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    callbacks=callbacks,
).history
# Out:
# Epoch 1/200
# 261/261 [==============================] - 131s 453ms/step - loss: 0.1426 - mae: 0.2624 - val_loss: 0.0188 - val_mae: 0.1071 - lr: 0.0010
# Epoch 2/200
# 261/261 [==============================] - 117s 447ms/step - loss: 0.0319 - mae: 0.1364 - val_loss: 0.0157 - val_mae: 0.0967 - lr: 0.0010
# Epoch 3/200
# 261/261 [==============================] - 118s 451ms/step - loss: 0.0214 - mae: 0.1100 - val_loss: 0.0116 - val_mae: 0.0719 - lr: 0.0010
# Epoch 4/200
# 261/261 [==============================] - 108s 415ms/step - loss: 0.0173 - mae: 0.0966 - val_loss: 0.0117 - val_mae: 0.0719 - lr: 0.0010
# Epoch 5/200
# 261/261 [==============================] - 109s 418ms/step - loss: 0.0152 - mae: 0.0890 - val_loss: 0.0117 - val_mae: 0.0740 - lr: 0.0010
# Epoch 6/200
# 261/261 [==============================] - 117s 448ms/step - loss: 0.0141 - mae: 0.0848 - val_loss: 0.0111 - val_mae: 0.0698 - lr: 0.0010
# Epoch 7/200
# 261/261 [==============================] - 109s 419ms/step - loss: 0.0132 - mae: 0.0814 - val_loss: 0.0118 - val_mae: 0.0768 - lr: 0.0010
# Epoch 8/200
# 261/261 [==============================] - 108s 415ms/step - loss: 0.0131 - mae: 0.0809 - val_loss: 0.0111 - val_mae: 0.0693 - lr: 0.0010
# Epoch 9/200
# 261/261 [==============================] - 115s 439ms/step - loss: 0.0124 - mae: 0.0784 - val_loss: 0.0109 - val_mae: 0.0685 - lr: 0.0010
# Epoch 10/200
# 261/261 [==============================] - 116s 443ms/step - loss: 0.0121 - mae: 0.0771 - val_loss: 0.0106 - val_mae: 0.0667 - lr: 0.0010
# Epoch 11/200
# 261/261 [==============================] - 108s 415ms/step - loss: 0.0119 - mae: 0.0761 - val_loss: 0.0107 - val_mae: 0.0709 - lr: 0.0010
# Epoch 12/200
# 261/261 [==============================] - 117s 450ms/step - loss: 0.0118 - mae: 0.0758 - val_loss: 0.0102 - val_mae: 0.0650 - lr: 0.0010
# Epoch 13/200
# 261/261 [==============================] - 117s 447ms/step - loss: 0.0115 - mae: 0.0745 - val_loss: 0.0102 - val_mae: 0.0646 - lr: 0.0010
# Epoch 14/200
# 261/261 [==============================] - 109s 419ms/step - loss: 0.0115 - mae: 0.0747 - val_loss: 0.0102 - val_mae: 0.0661 - lr: 0.0010
# Epoch 15/200
# 261/261 [==============================] - 109s 418ms/step - loss: 0.0113 - mae: 0.0741 - val_loss: 0.0103 - val_mae: 0.0670 - lr: 0.0010
# Epoch 16/200
# 261/261 [==============================] - 109s 419ms/step - loss: 0.0111 - mae: 0.0733 - val_loss: 0.0106 - val_mae: 0.0693 - lr: 0.0010
# Epoch 17/200
# 261/261 [==============================] - 118s 451ms/step - loss: 0.0110 - mae: 0.0725 - val_loss: 0.0100 - val_mae: 0.0657 - lr: 0.0010
# Epoch 18/200
# 261/261 [==============================] - 109s 419ms/step - loss: 0.0110 - mae: 0.0728 - val_loss: 0.0115 - val_mae: 0.0758 - lr: 0.0010
# Epoch 19/200
# 261/261 [==============================] - 109s 419ms/step - loss: 0.0109 - mae: 0.0725 - val_loss: 0.0106 - val_mae: 0.0700 - lr: 0.0010
# Epoch 20/200
# 261/261 [==============================] - 109s 419ms/step - loss: 0.0107 - mae: 0.0719 - val_loss: 0.0118 - val_mae: 0.0783 - lr: 0.0010
# Epoch 21/200
# 261/261 [==============================] - 117s 448ms/step - loss: 0.0106 - mae: 0.0713 - val_loss: 0.0098 - val_mae: 0.0647 - lr: 0.0010
# Epoch 22/200
# 261/261 [==============================] - 109s 419ms/step - loss: 0.0107 - mae: 0.0721 - val_loss: 0.0104 - val_mae: 0.0679 - lr: 0.0010
# Epoch 23/200
# 261/261 [==============================] - 109s 419ms/step - loss: 0.0106 - mae: 0.0714 - val_loss: 0.0100 - val_mae: 0.0669 - lr: 0.0010
# Epoch 24/200
# 261/261 [==============================] - 109s 419ms/step - loss: 0.0104 - mae: 0.0709 - val_loss: 0.0112 - val_mae: 0.0722 - lr: 0.0010
# Epoch 25/200
# 261/261 [==============================] - 108s 414ms/step - loss: 0.0104 - mae: 0.0709 - val_loss: 0.0104 - val_mae: 0.0699 - lr: 0.0010
# Epoch 26/200
# 261/261 [==============================] - 109s 418ms/step - loss: 0.0103 - mae: 0.0708 - val_loss: 0.0102 - val_mae: 0.0685 - lr: 0.0010
# Epoch 27/200
# 261/261 [==============================] - 109s 419ms/step - loss: 0.0103 - mae: 0.0706 - val_loss: 0.0114 - val_mae: 0.0752 - lr: 0.0010
# Epoch 28/200
# 261/261 [==============================] - 108s 415ms/step - loss: 0.0100 - mae: 0.0692 - val_loss: 0.0103 - val_mae: 0.0699 - lr: 0.0010
# Epoch 29/200
# 261/261 [==============================] - 108s 414ms/step - loss: 0.0101 - mae: 0.0698 - val_loss: 0.0106 - val_mae: 0.0700 - lr: 0.0010
# Epoch 30/200
# 261/261 [==============================] - 109s 418ms/step - loss: 0.0100 - mae: 0.0697 - val_loss: 0.0099 - val_mae: 0.0683 - lr: 0.0010
# Epoch 31/200
# 261/261 [==============================] - ETA: 0s - loss: 0.0099 - mae: 0.0689
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 261/261 [==============================] - 108s 415ms/step - loss: 0.0099 - mae: 0.0689 - val_loss: 0.0131 - val_mae: 0.0815 - lr: 0.0010
# Epoch 32/200
# 261/261 [==============================] - 116s 446ms/step - loss: 0.0092 - mae: 0.0661 - val_loss: 0.0088 - val_mae: 0.0596 - lr: 3.0000e-04
# Epoch 33/200
# 261/261 [==============================] - 108s 414ms/step - loss: 0.0091 - mae: 0.0656 - val_loss: 0.0100 - val_mae: 0.0694 - lr: 3.0000e-04
# Epoch 34/200
# 261/261 [==============================] - 109s 418ms/step - loss: 0.0089 - mae: 0.0651 - val_loss: 0.0090 - val_mae: 0.0627 - lr: 3.0000e-04
# Epoch 35/200
# 261/261 [==============================] - 116s 445ms/step - loss: 0.0089 - mae: 0.0649 - val_loss: 0.0087 - val_mae: 0.0596 - lr: 3.0000e-04
# Epoch 36/200
# 261/261 [==============================] - 109s 418ms/step - loss: 0.0089 - mae: 0.0651 - val_loss: 0.0090 - val_mae: 0.0628 - lr: 3.0000e-04
# Epoch 37/200
# 261/261 [==============================] - 109s 418ms/step - loss: 0.0088 - mae: 0.0646 - val_loss: 0.0089 - val_mae: 0.0617 - lr: 3.0000e-04
# Epoch 38/200
# 261/261 [==============================] - 109s 418ms/step - loss: 0.0088 - mae: 0.0646 - val_loss: 0.0087 - val_mae: 0.0600 - lr: 3.0000e-04
# Epoch 39/200
# 261/261 [==============================] - 108s 414ms/step - loss: 0.0087 - mae: 0.0643 - val_loss: 0.0088 - val_mae: 0.0614 - lr: 3.0000e-04
# Epoch 40/200
# 261/261 [==============================] - 108s 414ms/step - loss: 0.0086 - mae: 0.0641 - val_loss: 0.0089 - val_mae: 0.0620 - lr: 3.0000e-04
# Epoch 41/200
# 261/261 [==============================] - 109s 418ms/step - loss: 0.0085 - mae: 0.0637 - val_loss: 0.0089 - val_mae: 0.0625 - lr: 3.0000e-04
# Epoch 42/200
# 261/261 [==============================] - ETA: 0s - loss: 0.0085 - mae: 0.0637
# Epoch 42: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 261/261 [==============================] - 108s 414ms/step - loss: 0.0085 - mae: 0.0637 - val_loss: 0.0088 - val_mae: 0.0598 - lr: 3.0000e-04
# Epoch 43/200
# 261/261 [==============================] - 116s 446ms/step - loss: 0.0082 - mae: 0.0623 - val_loss: 0.0083 - val_mae: 0.0577 - lr: 9.0000e-05
# Epoch 44/200
# 261/261 [==============================] - 109s 419ms/step - loss: 0.0081 - mae: 0.0617 - val_loss: 0.0083 - val_mae: 0.0577 - lr: 9.0000e-05
# Epoch 45/200
# 255/261 [============================>.] - ETA: 2s - loss: 0.0080 - mae: 0.0614

# %%
plot_history(history, log_scale=True)

# %%
mse, mae = model.evaluate(X_val, y_val)
print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")

# %%
# Save the trained model
model.save('models/' + model.name)

# %% [markdown]
# ## Autoregressive model

# %%
# telescope is the number of timestamps that the model predicts
telescope = 9
# samples to predict is the total number of timestamps that we want to predict with the autoregressor model. This MUST be a factor of the telescope
samples_to_predict = telescope * 2
# test_sequences is the data we use to test the model. This will have to be changed with the Codalab data when submitting if we want to use this autoregressor model.
test_sequences = X_val[0:60]
sequences = np.copy(test_sequences)

i = 0
while i*telescope < samples_to_predict:
  pred = model.predict(sequences[:,:])
  for j in range(len(sequences)):
    for z in range(len(pred[j])):
      sequences[j] = np.delete(np.append(sequences[j], pred[j][z]), 0).reshape(-1, 1)
  i += 1

# %%
index = np.random.randint(len(test_sequences))
plot_data_and_target(test_sequences[index], sequences[index,-samples_to_predict:])
